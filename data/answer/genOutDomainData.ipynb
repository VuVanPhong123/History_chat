# %%
import json
import google.generativeai as genai
from time import sleep
import re
import random
from collections import defaultdict

# === Cấu hình API Key Gemini ===
genai.configure(api_key="")

output_file = "/kaggle/working/rejection_data_enhanced3.jsonl"
log_file = "/kaggle/working/rejection_enhanced_log3.txt"
batch_size = 6
target_samples = 2000
temperature = 0.9  # Tăng temperature để tăng tính ngẫu nhiên
max_retry = 3

# === DANH SÁCH MODEL FALLBACK ===
model_priority_list = [
    'gemini-2.5-flash-lite',
    'gemini-2.5-flash', 
    'gemini-2.5-pro',
    'gemini-2.0-flash',
    'gemini-2.0-flash-lite',
]

max_output_tokens = 8192

class DiversityEnhancedGenerator:
    def __init__(self):
        self.generated_themes = set()
        self.theme_categories = {
            "rejection": [
                "nấu ăn", "lập trình", "sức khỏe", "thể thao", "tài chính", 
                "du lịch", "thời trang", "làm đẹp", "xe cộ", "nhà đất",
                "giáo dục", "công việc", "mối quan hệ", "sở thích", "thú cưng",
                "phim ảnh", "âm nhạc", "sách", "công nghệ", "thời tiết"
            ],
            "question_types": [
                "hướng dẫn", "tư vấn", "so sánh", "kinh nghiệm", "đánh giá",
                "khuyến nghị", "giải thích", "phân tích", "dự đoán", "gợi ý"
            ],
            "question_formats": [
                "Làm thế nào để {action}?",
                "Bạn có thể tư vấn về {topic} không?",
                "Nên chọn {option_a} hay {option_b}?",
                "Kinh nghiệm về {topic} như thế nào?",
                "Cách tốt nhất để {action} là gì?",
                "Bạn biết gì về {topic}?",
                "Tôi muốn học về {topic}",
                "Có nên {action} không?",
                "Địa chỉ nào tốt cho {service}?",
                "Sản phẩm nào tốt cho {purpose}?"
            ]
        }
        
        self.rejection_responses = [
            "Xin lỗi, tôi chỉ có thể trả lời các câu hỏi về lịch sử Việt Nam. Câu hỏi về {topic} nằm ngoài phạm vi chuyên môn của tôi.",
            "Tôi xin lỗi, tôi chỉ tập trung vào lĩnh vực lịch sử Việt Nam. Tôi không thể hỗ trợ bạn với câu hỏi về {topic}.",
            "Tôi chỉ trả lời các câu hỏi liên quan đến lịch sử Việt Nam. Đối với thông tin về {topic}, bạn nên tham khảo các nguồn chuyên về lĩnh vực này.",
            "Xin lỗi, tôi không có chuyên môn về {topic}. Tôi chỉ có thể hỗ trợ các câu hỏi về lịch sử Việt Nam.",
            "Tôi chỉ chuyên về lịch sử Việt Nam. Câu hỏi về {topic} nằm ngoài khả năng của tôi."
        ]

    def get_diverse_prompt(self, batch_size):
        # Chọn ngẫu nhiên các chủ đề
        selected_themes = random.sample(self.theme_categories["rejection"], 
                                      min(8, len(self.theme_categories["rejection"])))
        selected_types = random.sample(self.theme_categories["question_types"], 3)
        
        prompt = f"""
HÃY TẠO {batch_size} MẪU HỘI THOẠI JSON CHO CHATBOT LỊCH SỬ VIỆT NAM VỚI ĐỘ ĐA DẠNG CAO:

YÊU CẦU QUAN TRỌNG VỀ ĐA DẠNG:
- MỖI mẫu phải có CHỦ ĐỀ KHÁC NHAU: {', '.join(selected_themes)}
- MỖI mẫu phải có DẠNG CÂU HỎI KHÁC NHAU: {', '.join(selected_types)}
- ĐẢM BẢO KHÔNG CÓ MẪU NÀO GIỐNG NHAU QUÁ 30%

HƯỚNG DẪN TẠO CÂU HỎI:
1. Sử dụng các cách diễn đạt đa dạng:
   - Câu hỏi trực tiếp: "Cách làm X?"
   - Câu nhờ tư vấn: "Bạn có thể tư vấn về Y?"  
   - Câu hỏi so sánh: "Giữa A và B cái nào tốt hơn?"
   - Câu hỏi kinh nghiệm: "Kinh nghiệm về Z?"
   - Câu yêu cầu: "Tôi muốn biết về W"

2. Đa dạng độ dài và cấu trúc:
   - Câu ngắn: "Cách nấu phở?"
   - Câu dài có ngữ cảnh: "Tôi đang muốn học nấu các món ăn Hà Nội, bạn có thể hướng dẫn không?"
   - Câu có nhiều thông tin: "Tôi cần tư vấn về đầu tư chứng khoán cho người mới bắt đầu"

3. Sử dụng từ ngữ tự nhiên, đa dạng

HƯỚNG DẪN TẠO CÂU TRẢ LỜI:
- Đa dạng cách từ chối, không dùng quá 2 lần cùng một công thức
- Giữ tone lịch sự, chuyên nghiệp
- Giải thích rõ giới hạn chuyên môn

VÍ DỤ ĐA DẠNG:
- "Làm thế nào để nấu phở bò ngon?" → "Xin lỗi, tôi chỉ chuyên về lịch sử..."
- "Bạn có thể tư vấn cho tôi về đầu tư chứng khoán?" → "Tôi xin lỗi, lĩnh vực tài chính..."
- "Kinh nghiệm du lịch Đà Lạt như thế nào?" → "Tôi chỉ trả lời các câu hỏi về lịch sử..."

ĐỊNH DẠNG JSON:
[
  {{
    "messages": [
      {{"role": "system", "content": "Bạn là chuyên gia lịch sử Việt Nam."}},
      {{"role": "user", "content": "QUESTION"}},
      {{"role": "assistant", "content": "ANSWER"}}
    ]
  }}
]

QUAN TRỌNG: CHỈ TRẢ VỀ JSON, KHÔNG THÊM VĂN BẢN NÀO KHÁC.
"""

        return prompt

def get_available_model():
    for model_name in model_priority_list:
        try:
            model = genai.GenerativeModel(model_name)
            print(f"✅ Sử dụng model: {model_name}")
            return model_name
        except Exception as e:
            print(f"❌ Model {model_name} không khả dụng: {e}")
            continue
    return model_priority_list[0]

def clean_json_response(text):
    cleaned = re.sub(r'```json\s*', '', text)
    cleaned = re.sub(r'\s*```', '', cleaned)
    cleaned = cleaned.strip()
    cleaned = re.sub(r'^[^{[]*', '', cleaned)
    cleaned = re.sub(r'[^}\]]*$', '', cleaned)
    return cleaned

def repair_truncated_json(json_str):
    if not json_str.strip():
        return json_str
        
    open_braces = json_str.count('{')
    close_braces = json_str.count('}')
    open_brackets = json_str.count('[')
    close_brackets = json_str.count(']')
    
    repaired = json_str
    
    if open_braces > close_braces:
        repaired += '}' * (open_braces - close_braces)
    if open_brackets > close_brackets:
        repaired += ']' * (open_brackets - close_brackets)
    
    return repaired

def extract_and_parse_json(response_text):
    print(f"🔧 Đang xử lý response dài {len(response_text)} chars...")
    
    cleaned_text = clean_json_response(response_text)
    
    try:
        json_data = json.loads(cleaned_text)
        print("✅ Parse trực tiếp thành công")
        return json_data
    except json.JSONDecodeError:
        print("❌ Parse trực tiếp thất bại")
    
    array_pattern = r'\[\s*\{[\s\S]*?\}\s*\]'
    array_matches = re.findall(array_pattern, cleaned_text, re.DOTALL)
    
    if array_matches:
        json_str = max(array_matches, key=len)
        json_str_repaired = repair_truncated_json(json_str)
        
        try:
            json_data = json.loads(json_str_repaired)
            print("✅ Parse JSON đã sửa thành công")
            return json_data
        except json.JSONDecodeError:
            print("❌ Vẫn lỗi JSON sau khi sửa")
    
    start_idx = cleaned_text.find('[')
    end_idx = cleaned_text.rfind(']')
    
    if start_idx != -1 and end_idx != -1 and end_idx > start_idx:
        json_str = cleaned_text[start_idx:end_idx+1]
        json_str_repaired = repair_truncated_json(json_str)
        
        try:
            json_data = json.loads(json_str_repaired)
            print("✅ Parse JSON manual thành công")
            return json_data
        except json.JSONDecodeError:
            print("❌ Lỗi parse JSON manual")
    
    raise ValueError("Không thể trích xuất JSON từ response")

def generate_rejection_batch(batch_size):
    generator = DiversityEnhancedGenerator()
    prompt = generator.get_diverse_prompt(batch_size)

    current_model = get_available_model()
    
    for attempt in range(1, max_retry + 1):
        try:
            print(f"🔄 Attempt {attempt} với model {current_model}...")
            
            model = genai.GenerativeModel(current_model)
            response = model.generate_content(
                prompt,
                generation_config=genai.types.GenerationConfig(
                    temperature=temperature,
                    max_output_tokens=max_output_tokens,
                    top_p=0.9
                )
            )
            
            response_text = response.text.strip()
            print(f"📄 Raw response length: {len(response_text)} chars")
            
            json_data = extract_and_parse_json(response_text)
            
            if not isinstance(json_data, list):
                raise ValueError("Kết quả không phải là list")
                
            print(f"✅ Đã tạo được {len(json_data)} samples")
                
            for i, item in enumerate(json_data):
                if "messages" not in item:
                    raise ValueError(f"Thiếu key 'messages' trong item {i}")
                    
            return json_data
            
        except Exception as e:
            print(f"❌ Lỗi attempt {attempt}: {str(e)[:200]}")
            
            if attempt < max_retry:
                next_model_index = (model_priority_list.index(current_model) + 1) % len(model_priority_list)
                current_model = model_priority_list[next_model_index]
                print(f"🔄 Chuyển sang model: {current_model}")
                sleep(3)
            else:
                return []

def create_fallback_rejection_batch(batch_size):
    fallback_data = []
    generator = DiversityEnhancedGenerator()
    
    for i in range(batch_size):
        theme = random.choice(generator.theme_categories["rejection"])
        question_format = random.choice(generator.theme_categories["question_formats"])
        response_template = random.choice(generator.rejection_responses)
        
        if "{action}" in question_format:
            question = question_format.format(action=f"thực hiện {theme}")
        elif "{topic}" in question_format:
            question = question_format.format(topic=theme)
        elif "{option_a}" in question_format:
            question = question_format.format(option_a=f"phương án A cho {theme}", option_b=f"phương án B cho {theme}")
        else:
            question = question_format.format(service=theme, purpose=theme)
            
        answer = response_template.format(topic=theme)
        
        messages = [
            {"role": "system", "content": "Bạn là chuyên gia lịch sử Việt Nam."},
            {"role": "user", "content": question},
            {"role": "assistant", "content": answer}
        ]
        fallback_data.append({"messages": messages})
    
    return fallback_data

# === XỬ LÝ CHÍNH ===
processed_count = 0
diversity_generator = DiversityEnhancedGenerator()

print(f"🎯 Bắt đầu tạo {target_samples} samples data từ chối với độ đa dạng cao...")

with open(output_file, "w", encoding="utf-8") as f_out, \
     open(log_file, "w", encoding="utf-8") as f_log:

    while processed_count < target_samples:
        current_batch_size = min(batch_size, target_samples - processed_count)
        print(f"\n🚀 Đang tạo batch {processed_count + 1} đến {processed_count + current_batch_size}...")
        
        batch_data = generate_rejection_batch(current_batch_size)
        
        if not batch_data:
            print("🔄 Sử dụng fallback...")
            batch_data = create_fallback_rejection_batch(current_batch_size)
        
        for data in batch_data:
            f_out.write(json.dumps(data, ensure_ascii=False) + "\n")
            processed_count += 1
        
        f_log.write(f"Đã tạo {processed_count}/{target_samples} samples\n")
        print(f"✅ Đã tạo {processed_count}/{target_samples} samples")
        
        if processed_count < target_samples:
            sleep(5)

print(f"\n🎉 Hoàn tất! Đã tạo {processed_count} samples data từ chối với độ đa dạng cao.")
# Out:
# 🎯 Bắt đầu tạo 2000 samples data từ chối với độ đa dạng cao...
#
# 🚀 Đang tạo batch 1 đến 6...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 6953 chars
# 🔧 Đang xử lý response dài 6953 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 6/2000 samples
#
# 🚀 Đang tạo batch 7 đến 12...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4635 chars
# 🔧 Đang xử lý response dài 4635 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 12/2000 samples
#
# 🚀 Đang tạo batch 13 đến 18...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3109 chars
# 🔧 Đang xử lý response dài 3109 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 18/2000 samples
#
# 🚀 Đang tạo batch 19 đến 24...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4016 chars
# 🔧 Đang xử lý response dài 4016 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 24/2000 samples
#
# 🚀 Đang tạo batch 25 đến 30...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4706 chars
# 🔧 Đang xử lý response dài 4706 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 30/2000 samples
#
# 🚀 Đang tạo batch 31 đến 36...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3301 chars
# 🔧 Đang xử lý response dài 3301 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 36/2000 samples
#
# 🚀 Đang tạo batch 37 đến 42...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5249 chars
# 🔧 Đang xử lý response dài 5249 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 42/2000 samples
#
# 🚀 Đang tạo batch 43 đến 48...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3644 chars
# 🔧 Đang xử lý response dài 3644 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 48/2000 samples
#
# 🚀 Đang tạo batch 49 đến 54...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3939 chars
# 🔧 Đang xử lý response dài 3939 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 54/2000 samples
#
# 🚀 Đang tạo batch 55 đến 60...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5466 chars
# 🔧 Đang xử lý response dài 5466 chars...
# ❌ Parse trực tiếp thất bại
# ❌ Vẫn lỗi JSON sau khi sửa
# ❌ Lỗi parse JSON manual
# ❌ Lỗi attempt 1: Không thể trích xuất JSON từ response
# 🔄 Chuyển sang model: gemini-2.5-flash
# 🔄 Attempt 2 với model gemini-2.5-flash...
# 📄 Raw response length: 3143 chars
# 🔧 Đang xử lý response dài 3143 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 60/2000 samples
#
# 🚀 Đang tạo batch 61 đến 66...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 7090 chars
# 🔧 Đang xử lý response dài 7090 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 66/2000 samples
#
# 🚀 Đang tạo batch 67 đến 72...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4407 chars
# 🔧 Đang xử lý response dài 4407 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 72/2000 samples
#
# 🚀 Đang tạo batch 73 đến 78...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4080 chars
# 🔧 Đang xử lý response dài 4080 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 78/2000 samples
#
# 🚀 Đang tạo batch 79 đến 84...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2635 chars
# 🔧 Đang xử lý response dài 2635 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 84/2000 samples
#
# 🚀 Đang tạo batch 85 đến 90...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4430 chars
# 🔧 Đang xử lý response dài 4430 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 90/2000 samples
#
# 🚀 Đang tạo batch 91 đến 96...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5598 chars
# 🔧 Đang xử lý response dài 5598 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 96/2000 samples
#
# 🚀 Đang tạo batch 97 đến 102...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4587 chars
# 🔧 Đang xử lý response dài 4587 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 102/2000 samples
#
# 🚀 Đang tạo batch 103 đến 108...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 6198 chars
# 🔧 Đang xử lý response dài 6198 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 108/2000 samples
#
# 🚀 Đang tạo batch 109 đến 114...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4743 chars
# 🔧 Đang xử lý response dài 4743 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 114/2000 samples
#
# 🚀 Đang tạo batch 115 đến 120...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2694 chars
# 🔧 Đang xử lý response dài 2694 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 120/2000 samples
#
# 🚀 Đang tạo batch 121 đến 126...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3533 chars
# 🔧 Đang xử lý response dài 3533 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 126/2000 samples
#
# 🚀 Đang tạo batch 127 đến 132...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3685 chars
# 🔧 Đang xử lý response dài 3685 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 132/2000 samples
#
# 🚀 Đang tạo batch 133 đến 138...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3556 chars
# 🔧 Đang xử lý response dài 3556 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 138/2000 samples
#
# 🚀 Đang tạo batch 139 đến 144...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3478 chars
# 🔧 Đang xử lý response dài 3478 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 144/2000 samples
#
# 🚀 Đang tạo batch 145 đến 150...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 6713 chars
# 🔧 Đang xử lý response dài 6713 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 150/2000 samples
#
# 🚀 Đang tạo batch 151 đến 156...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4204 chars
# 🔧 Đang xử lý response dài 4204 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 156/2000 samples
#
# 🚀 Đang tạo batch 157 đến 162...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4590 chars
# 🔧 Đang xử lý response dài 4590 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 162/2000 samples
#
# 🚀 Đang tạo batch 163 đến 168...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4611 chars
# 🔧 Đang xử lý response dài 4611 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 168/2000 samples
#
# 🚀 Đang tạo batch 169 đến 174...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4400 chars
# 🔧 Đang xử lý response dài 4400 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 174/2000 samples
#
# 🚀 Đang tạo batch 175 đến 180...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3525 chars
# 🔧 Đang xử lý response dài 3525 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 180/2000 samples
#
# 🚀 Đang tạo batch 181 đến 186...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2830 chars
# 🔧 Đang xử lý response dài 2830 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 186/2000 samples
#
# 🚀 Đang tạo batch 187 đến 192...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3388 chars
# 🔧 Đang xử lý response dài 3388 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 192/2000 samples
#
# 🚀 Đang tạo batch 193 đến 198...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3128 chars
# 🔧 Đang xử lý response dài 3128 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 198/2000 samples
#
# 🚀 Đang tạo batch 199 đến 204...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5293 chars
# 🔧 Đang xử lý response dài 5293 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 204/2000 samples
#
# 🚀 Đang tạo batch 205 đến 210...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4468 chars
# 🔧 Đang xử lý response dài 4468 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 210/2000 samples
#
# 🚀 Đang tạo batch 211 đến 216...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3473 chars
# 🔧 Đang xử lý response dài 3473 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 216/2000 samples
#
# 🚀 Đang tạo batch 217 đến 222...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3888 chars
# 🔧 Đang xử lý response dài 3888 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 222/2000 samples
#
# 🚀 Đang tạo batch 223 đến 228...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3306 chars
# 🔧 Đang xử lý response dài 3306 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 228/2000 samples
#
# 🚀 Đang tạo batch 229 đến 234...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4843 chars
# 🔧 Đang xử lý response dài 4843 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 234/2000 samples
#
# 🚀 Đang tạo batch 235 đến 240...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4101 chars
# 🔧 Đang xử lý response dài 4101 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 240/2000 samples
#
# 🚀 Đang tạo batch 241 đến 246...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3200 chars
# 🔧 Đang xử lý response dài 3200 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 246/2000 samples
#
# 🚀 Đang tạo batch 247 đến 252...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4860 chars
# 🔧 Đang xử lý response dài 4860 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 252/2000 samples
#
# 🚀 Đang tạo batch 253 đến 258...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4363 chars
# 🔧 Đang xử lý response dài 4363 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 258/2000 samples
#
# 🚀 Đang tạo batch 259 đến 264...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3787 chars
# 🔧 Đang xử lý response dài 3787 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 264/2000 samples
#
# 🚀 Đang tạo batch 265 đến 270...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3416 chars
# 🔧 Đang xử lý response dài 3416 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 270/2000 samples
#
# 🚀 Đang tạo batch 271 đến 276...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3514 chars
# 🔧 Đang xử lý response dài 3514 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 276/2000 samples
#
# 🚀 Đang tạo batch 277 đến 282...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3885 chars
# 🔧 Đang xử lý response dài 3885 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 282/2000 samples
#
# 🚀 Đang tạo batch 283 đến 288...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4068 chars
# 🔧 Đang xử lý response dài 4068 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 288/2000 samples
#
# 🚀 Đang tạo batch 289 đến 294...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4678 chars
# 🔧 Đang xử lý response dài 4678 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 294/2000 samples
#
# 🚀 Đang tạo batch 295 đến 300...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3636 chars
# 🔧 Đang xử lý response dài 3636 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 300/2000 samples
#
# 🚀 Đang tạo batch 301 đến 306...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5728 chars
# 🔧 Đang xử lý response dài 5728 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 306/2000 samples
#
# 🚀 Đang tạo batch 307 đến 312...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3347 chars
# 🔧 Đang xử lý response dài 3347 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 312/2000 samples
#
# 🚀 Đang tạo batch 313 đến 318...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3844 chars
# 🔧 Đang xử lý response dài 3844 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 318/2000 samples
#
# 🚀 Đang tạo batch 319 đến 324...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3697 chars
# 🔧 Đang xử lý response dài 3697 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 324/2000 samples
#
# 🚀 Đang tạo batch 325 đến 330...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4305 chars
# 🔧 Đang xử lý response dài 4305 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 330/2000 samples
#
# 🚀 Đang tạo batch 331 đến 336...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3948 chars
# 🔧 Đang xử lý response dài 3948 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 336/2000 samples
#
# 🚀 Đang tạo batch 337 đến 342...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4928 chars
# 🔧 Đang xử lý response dài 4928 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 342/2000 samples
#
# 🚀 Đang tạo batch 343 đến 348...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5183 chars
# 🔧 Đang xử lý response dài 5183 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 348/2000 samples
#
# 🚀 Đang tạo batch 349 đến 354...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3099 chars
# 🔧 Đang xử lý response dài 3099 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 354/2000 samples
#
# 🚀 Đang tạo batch 355 đến 360...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3372 chars
# 🔧 Đang xử lý response dài 3372 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 360/2000 samples
#
# 🚀 Đang tạo batch 361 đến 366...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4320 chars
# 🔧 Đang xử lý response dài 4320 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 366/2000 samples
#
# 🚀 Đang tạo batch 367 đến 372...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3063 chars
# 🔧 Đang xử lý response dài 3063 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 372/2000 samples
#
# 🚀 Đang tạo batch 373 đến 378...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4157 chars
# 🔧 Đang xử lý response dài 4157 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 378/2000 samples
#
# 🚀 Đang tạo batch 379 đến 384...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3805 chars
# 🔧 Đang xử lý response dài 3805 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 384/2000 samples
#
# 🚀 Đang tạo batch 385 đến 390...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4040 chars
# 🔧 Đang xử lý response dài 4040 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 390/2000 samples
#
# 🚀 Đang tạo batch 391 đến 396...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2956 chars
# 🔧 Đang xử lý response dài 2956 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 396/2000 samples
#
# 🚀 Đang tạo batch 397 đến 402...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5913 chars
# 🔧 Đang xử lý response dài 5913 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 402/2000 samples
#
# 🚀 Đang tạo batch 403 đến 408...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2637 chars
# 🔧 Đang xử lý response dài 2637 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 408/2000 samples
#
# 🚀 Đang tạo batch 409 đến 414...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5318 chars
# 🔧 Đang xử lý response dài 5318 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 414/2000 samples
#
# 🚀 Đang tạo batch 415 đến 420...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5650 chars
# 🔧 Đang xử lý response dài 5650 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 420/2000 samples
#
# 🚀 Đang tạo batch 421 đến 426...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4534 chars
# 🔧 Đang xử lý response dài 4534 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 426/2000 samples
#
# 🚀 Đang tạo batch 427 đến 432...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3892 chars
# 🔧 Đang xử lý response dài 3892 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 432/2000 samples
#
# 🚀 Đang tạo batch 433 đến 438...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4771 chars
# 🔧 Đang xử lý response dài 4771 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 438/2000 samples
#
# 🚀 Đang tạo batch 439 đến 444...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3921 chars
# 🔧 Đang xử lý response dài 3921 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 444/2000 samples
#
# 🚀 Đang tạo batch 445 đến 450...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5078 chars
# 🔧 Đang xử lý response dài 5078 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 450/2000 samples
#
# 🚀 Đang tạo batch 451 đến 456...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4069 chars
# 🔧 Đang xử lý response dài 4069 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 456/2000 samples
#
# 🚀 Đang tạo batch 457 đến 462...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3500 chars
# 🔧 Đang xử lý response dài 3500 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 462/2000 samples
#
# 🚀 Đang tạo batch 463 đến 468...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5023 chars
# 🔧 Đang xử lý response dài 5023 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 468/2000 samples
#
# 🚀 Đang tạo batch 469 đến 474...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3988 chars
# 🔧 Đang xử lý response dài 3988 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 474/2000 samples
#
# 🚀 Đang tạo batch 475 đến 480...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3445 chars
# 🔧 Đang xử lý response dài 3445 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 480/2000 samples
#
# 🚀 Đang tạo batch 481 đến 486...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2768 chars
# 🔧 Đang xử lý response dài 2768 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 486/2000 samples
#
# 🚀 Đang tạo batch 487 đến 492...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4162 chars
# 🔧 Đang xử lý response dài 4162 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 492/2000 samples
#
# 🚀 Đang tạo batch 493 đến 498...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3559 chars
# 🔧 Đang xử lý response dài 3559 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 498/2000 samples
#
# 🚀 Đang tạo batch 499 đến 504...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4090 chars
# 🔧 Đang xử lý response dài 4090 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 504/2000 samples
#
# 🚀 Đang tạo batch 505 đến 510...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2980 chars
# 🔧 Đang xử lý response dài 2980 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 510/2000 samples
#
# 🚀 Đang tạo batch 511 đến 516...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5299 chars
# 🔧 Đang xử lý response dài 5299 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 516/2000 samples
#
# 🚀 Đang tạo batch 517 đến 522...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3755 chars
# 🔧 Đang xử lý response dài 3755 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 522/2000 samples
#
# 🚀 Đang tạo batch 523 đến 528...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4315 chars
# 🔧 Đang xử lý response dài 4315 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 528/2000 samples
#
# 🚀 Đang tạo batch 529 đến 534...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4525 chars
# 🔧 Đang xử lý response dài 4525 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 534/2000 samples
#
# 🚀 Đang tạo batch 535 đến 540...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3893 chars
# 🔧 Đang xử lý response dài 3893 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 540/2000 samples
#
# 🚀 Đang tạo batch 541 đến 546...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4662 chars
# 🔧 Đang xử lý response dài 4662 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 546/2000 samples
#
# 🚀 Đang tạo batch 547 đến 552...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5397 chars
# 🔧 Đang xử lý response dài 5397 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 552/2000 samples
#
# 🚀 Đang tạo batch 553 đến 558...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4259 chars
# 🔧 Đang xử lý response dài 4259 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 558/2000 samples
#
# 🚀 Đang tạo batch 559 đến 564...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3604 chars
# 🔧 Đang xử lý response dài 3604 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 564/2000 samples
#
# 🚀 Đang tạo batch 565 đến 570...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3533 chars
# 🔧 Đang xử lý response dài 3533 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 570/2000 samples
#
# 🚀 Đang tạo batch 571 đến 576...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4840 chars
# 🔧 Đang xử lý response dài 4840 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 576/2000 samples
#
# 🚀 Đang tạo batch 577 đến 582...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3124 chars
# 🔧 Đang xử lý response dài 3124 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 582/2000 samples
#
# 🚀 Đang tạo batch 583 đến 588...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4043 chars
# 🔧 Đang xử lý response dài 4043 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 588/2000 samples
#
# 🚀 Đang tạo batch 589 đến 594...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 6567 chars
# 🔧 Đang xử lý response dài 6567 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 594/2000 samples
#
# 🚀 Đang tạo batch 595 đến 600...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2926 chars
# 🔧 Đang xử lý response dài 2926 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 600/2000 samples
#
# 🚀 Đang tạo batch 601 đến 606...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4615 chars
# 🔧 Đang xử lý response dài 4615 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 606/2000 samples
#
# 🚀 Đang tạo batch 607 đến 612...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 6051 chars
# 🔧 Đang xử lý response dài 6051 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 612/2000 samples
#
# 🚀 Đang tạo batch 613 đến 618...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3227 chars
# 🔧 Đang xử lý response dài 3227 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 618/2000 samples
#
# 🚀 Đang tạo batch 619 đến 624...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3530 chars
# 🔧 Đang xử lý response dài 3530 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 624/2000 samples
#
# 🚀 Đang tạo batch 625 đến 630...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3798 chars
# 🔧 Đang xử lý response dài 3798 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 630/2000 samples
#
# 🚀 Đang tạo batch 631 đến 636...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4136 chars
# 🔧 Đang xử lý response dài 4136 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 636/2000 samples
#
# 🚀 Đang tạo batch 637 đến 642...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2673 chars
# 🔧 Đang xử lý response dài 2673 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 642/2000 samples
#
# 🚀 Đang tạo batch 643 đến 648...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3708 chars
# 🔧 Đang xử lý response dài 3708 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 648/2000 samples
#
# 🚀 Đang tạo batch 649 đến 654...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3315 chars
# 🔧 Đang xử lý response dài 3315 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 654/2000 samples
#
# 🚀 Đang tạo batch 655 đến 660...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4364 chars
# 🔧 Đang xử lý response dài 4364 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 660/2000 samples
#
# 🚀 Đang tạo batch 661 đến 666...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4372 chars
# 🔧 Đang xử lý response dài 4372 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 666/2000 samples
#
# 🚀 Đang tạo batch 667 đến 672...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3675 chars
# 🔧 Đang xử lý response dài 3675 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 672/2000 samples
#
# 🚀 Đang tạo batch 673 đến 678...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2637 chars
# 🔧 Đang xử lý response dài 2637 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 678/2000 samples
#
# 🚀 Đang tạo batch 679 đến 684...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3509 chars
# 🔧 Đang xử lý response dài 3509 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 684/2000 samples
#
# 🚀 Đang tạo batch 685 đến 690...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3597 chars
# 🔧 Đang xử lý response dài 3597 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 690/2000 samples
#
# 🚀 Đang tạo batch 691 đến 696...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4797 chars
# 🔧 Đang xử lý response dài 4797 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 696/2000 samples
#
# 🚀 Đang tạo batch 697 đến 702...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3541 chars
# 🔧 Đang xử lý response dài 3541 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 702/2000 samples
#
# 🚀 Đang tạo batch 703 đến 708...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4365 chars
# 🔧 Đang xử lý response dài 4365 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 708/2000 samples
#
# 🚀 Đang tạo batch 709 đến 714...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3803 chars
# 🔧 Đang xử lý response dài 3803 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 714/2000 samples
#
# 🚀 Đang tạo batch 715 đến 720...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5786 chars
# 🔧 Đang xử lý response dài 5786 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 720/2000 samples
#
# 🚀 Đang tạo batch 721 đến 726...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4213 chars
# 🔧 Đang xử lý response dài 4213 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 726/2000 samples
#
# 🚀 Đang tạo batch 727 đến 732...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3442 chars
# 🔧 Đang xử lý response dài 3442 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 732/2000 samples
#
# 🚀 Đang tạo batch 733 đến 738...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2912 chars
# 🔧 Đang xử lý response dài 2912 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 738/2000 samples
#
# 🚀 Đang tạo batch 739 đến 744...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2779 chars
# 🔧 Đang xử lý response dài 2779 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 744/2000 samples
#
# 🚀 Đang tạo batch 745 đến 750...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4224 chars
# 🔧 Đang xử lý response dài 4224 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 750/2000 samples
#
# 🚀 Đang tạo batch 751 đến 756...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2667 chars
# 🔧 Đang xử lý response dài 2667 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 756/2000 samples
#
# 🚀 Đang tạo batch 757 đến 762...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3938 chars
# 🔧 Đang xử lý response dài 3938 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 762/2000 samples
#
# 🚀 Đang tạo batch 763 đến 768...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3621 chars
# 🔧 Đang xử lý response dài 3621 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 768/2000 samples
#
# 🚀 Đang tạo batch 769 đến 774...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4743 chars
# 🔧 Đang xử lý response dài 4743 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 774/2000 samples
#
# 🚀 Đang tạo batch 775 đến 780...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4216 chars
# 🔧 Đang xử lý response dài 4216 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 780/2000 samples
#
# 🚀 Đang tạo batch 781 đến 786...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3922 chars
# 🔧 Đang xử lý response dài 3922 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 786/2000 samples
#
# 🚀 Đang tạo batch 787 đến 792...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3374 chars
# 🔧 Đang xử lý response dài 3374 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 792/2000 samples
#
# 🚀 Đang tạo batch 793 đến 798...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3360 chars
# 🔧 Đang xử lý response dài 3360 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 798/2000 samples
#
# 🚀 Đang tạo batch 799 đến 804...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4641 chars
# 🔧 Đang xử lý response dài 4641 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 804/2000 samples
#
# 🚀 Đang tạo batch 805 đến 810...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4675 chars
# 🔧 Đang xử lý response dài 4675 chars...
# ❌ Parse trực tiếp thất bại
# ❌ Vẫn lỗi JSON sau khi sửa
# ❌ Lỗi parse JSON manual
# ❌ Lỗi attempt 1: Không thể trích xuất JSON từ response
# 🔄 Chuyển sang model: gemini-2.5-flash
# 🔄 Attempt 2 với model gemini-2.5-flash...
# 📄 Raw response length: 3551 chars
# 🔧 Đang xử lý response dài 3551 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 810/2000 samples
#
# 🚀 Đang tạo batch 811 đến 816...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4035 chars
# 🔧 Đang xử lý response dài 4035 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 816/2000 samples
#
# 🚀 Đang tạo batch 817 đến 822...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4276 chars
# 🔧 Đang xử lý response dài 4276 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 822/2000 samples
#
# 🚀 Đang tạo batch 823 đến 828...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4568 chars
# 🔧 Đang xử lý response dài 4568 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 828/2000 samples
#
# 🚀 Đang tạo batch 829 đến 834...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3505 chars
# 🔧 Đang xử lý response dài 3505 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 834/2000 samples
#
# 🚀 Đang tạo batch 835 đến 840...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3814 chars
# 🔧 Đang xử lý response dài 3814 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 840/2000 samples
#
# 🚀 Đang tạo batch 841 đến 846...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2551 chars
# 🔧 Đang xử lý response dài 2551 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 846/2000 samples
#
# 🚀 Đang tạo batch 847 đến 852...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4134 chars
# 🔧 Đang xử lý response dài 4134 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 852/2000 samples
#
# 🚀 Đang tạo batch 853 đến 858...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4928 chars
# 🔧 Đang xử lý response dài 4928 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 858/2000 samples
#
# 🚀 Đang tạo batch 859 đến 864...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5437 chars
# 🔧 Đang xử lý response dài 5437 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 864/2000 samples
#
# 🚀 Đang tạo batch 865 đến 870...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5099 chars
# 🔧 Đang xử lý response dài 5099 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 870/2000 samples
#
# 🚀 Đang tạo batch 871 đến 876...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3959 chars
# 🔧 Đang xử lý response dài 3959 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 876/2000 samples
#
# 🚀 Đang tạo batch 877 đến 882...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4204 chars
# 🔧 Đang xử lý response dài 4204 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 882/2000 samples
#
# 🚀 Đang tạo batch 883 đến 888...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3662 chars
# 🔧 Đang xử lý response dài 3662 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 888/2000 samples
#
# 🚀 Đang tạo batch 889 đến 894...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3472 chars
# 🔧 Đang xử lý response dài 3472 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 894/2000 samples
#
# 🚀 Đang tạo batch 895 đến 900...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3928 chars
# 🔧 Đang xử lý response dài 3928 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 900/2000 samples
#
# 🚀 Đang tạo batch 901 đến 906...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3150 chars
# 🔧 Đang xử lý response dài 3150 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 906/2000 samples
#
# 🚀 Đang tạo batch 907 đến 912...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3315 chars
# 🔧 Đang xử lý response dài 3315 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 912/2000 samples
#
# 🚀 Đang tạo batch 913 đến 918...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3583 chars
# 🔧 Đang xử lý response dài 3583 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 918/2000 samples
#
# 🚀 Đang tạo batch 919 đến 924...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4481 chars
# 🔧 Đang xử lý response dài 4481 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 924/2000 samples
#
# 🚀 Đang tạo batch 925 đến 930...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4575 chars
# 🔧 Đang xử lý response dài 4575 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 930/2000 samples
#
# 🚀 Đang tạo batch 931 đến 936...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2947 chars
# 🔧 Đang xử lý response dài 2947 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 936/2000 samples
#
# 🚀 Đang tạo batch 937 đến 942...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3926 chars
# 🔧 Đang xử lý response dài 3926 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 942/2000 samples
#
# 🚀 Đang tạo batch 943 đến 948...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2634 chars
# 🔧 Đang xử lý response dài 2634 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 948/2000 samples
#
# 🚀 Đang tạo batch 949 đến 954...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3703 chars
# 🔧 Đang xử lý response dài 3703 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 954/2000 samples
#
# 🚀 Đang tạo batch 955 đến 960...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3859 chars
# 🔧 Đang xử lý response dài 3859 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 960/2000 samples
#
# 🚀 Đang tạo batch 961 đến 966...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5207 chars
# 🔧 Đang xử lý response dài 5207 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 966/2000 samples
#
# 🚀 Đang tạo batch 967 đến 972...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2516 chars
# 🔧 Đang xử lý response dài 2516 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 972/2000 samples
#
# 🚀 Đang tạo batch 973 đến 978...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4554 chars
# 🔧 Đang xử lý response dài 4554 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 978/2000 samples
#
# 🚀 Đang tạo batch 979 đến 984...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4586 chars
# 🔧 Đang xử lý response dài 4586 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 984/2000 samples
#
# 🚀 Đang tạo batch 985 đến 990...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3603 chars
# 🔧 Đang xử lý response dài 3603 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 990/2000 samples
#
# 🚀 Đang tạo batch 991 đến 996...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3615 chars
# 🔧 Đang xử lý response dài 3615 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 996/2000 samples
#
# 🚀 Đang tạo batch 997 đến 1002...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3445 chars
# 🔧 Đang xử lý response dài 3445 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1002/2000 samples
#
# 🚀 Đang tạo batch 1003 đến 1008...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4018 chars
# 🔧 Đang xử lý response dài 4018 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1008/2000 samples
#
# 🚀 Đang tạo batch 1009 đến 1014...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4536 chars
# 🔧 Đang xử lý response dài 4536 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1014/2000 samples
#
# 🚀 Đang tạo batch 1015 đến 1020...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3326 chars
# 🔧 Đang xử lý response dài 3326 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1020/2000 samples
#
# 🚀 Đang tạo batch 1021 đến 1026...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3293 chars
# 🔧 Đang xử lý response dài 3293 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1026/2000 samples
#
# 🚀 Đang tạo batch 1027 đến 1032...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3785 chars
# 🔧 Đang xử lý response dài 3785 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1032/2000 samples
#
# 🚀 Đang tạo batch 1033 đến 1038...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4126 chars
# 🔧 Đang xử lý response dài 4126 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1038/2000 samples
#
# 🚀 Đang tạo batch 1039 đến 1044...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3766 chars
# 🔧 Đang xử lý response dài 3766 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1044/2000 samples
#
# 🚀 Đang tạo batch 1045 đến 1050...
# ...
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5961 chars
# 🔧 Đang xử lý response dài 5961 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1680/2000 samples
#
# 🚀 Đang tạo batch 1681 đến 1686...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3152 chars
# 🔧 Đang xử lý response dài 3152 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1686/2000 samples
#
# 🚀 Đang tạo batch 1687 đến 1692...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4521 chars
# 🔧 Đang xử lý response dài 4521 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1692/2000 samples
#
# 🚀 Đang tạo batch 1693 đến 1698...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3857 chars
# 🔧 Đang xử lý response dài 3857 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1698/2000 samples
#
# 🚀 Đang tạo batch 1699 đến 1704...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4737 chars
# 🔧 Đang xử lý response dài 4737 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1704/2000 samples
#
# 🚀 Đang tạo batch 1705 đến 1710...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3673 chars
# 🔧 Đang xử lý response dài 3673 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1710/2000 samples
#
# 🚀 Đang tạo batch 1711 đến 1716...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3537 chars
# 🔧 Đang xử lý response dài 3537 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1716/2000 samples
#
# 🚀 Đang tạo batch 1717 đến 1722...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3328 chars
# 🔧 Đang xử lý response dài 3328 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1722/2000 samples
#
# 🚀 Đang tạo batch 1723 đến 1728...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3398 chars
# 🔧 Đang xử lý response dài 3398 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1728/2000 samples
#
# 🚀 Đang tạo batch 1729 đến 1734...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3970 chars
# 🔧 Đang xử lý response dài 3970 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1734/2000 samples
#
# 🚀 Đang tạo batch 1735 đến 1740...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2743 chars
# 🔧 Đang xử lý response dài 2743 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1740/2000 samples
#
# 🚀 Đang tạo batch 1741 đến 1746...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2593 chars
# 🔧 Đang xử lý response dài 2593 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1746/2000 samples
#
# 🚀 Đang tạo batch 1747 đến 1752...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5404 chars
# 🔧 Đang xử lý response dài 5404 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1752/2000 samples
#
# 🚀 Đang tạo batch 1753 đến 1758...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3652 chars
# 🔧 Đang xử lý response dài 3652 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1758/2000 samples
#
# 🚀 Đang tạo batch 1759 đến 1764...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3243 chars
# 🔧 Đang xử lý response dài 3243 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1764/2000 samples
#
# 🚀 Đang tạo batch 1765 đến 1770...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5104 chars
# 🔧 Đang xử lý response dài 5104 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1770/2000 samples
#
# 🚀 Đang tạo batch 1771 đến 1776...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4087 chars
# 🔧 Đang xử lý response dài 4087 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1776/2000 samples
#
# 🚀 Đang tạo batch 1777 đến 1782...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4109 chars
# 🔧 Đang xử lý response dài 4109 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1782/2000 samples
#
# 🚀 Đang tạo batch 1783 đến 1788...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3385 chars
# 🔧 Đang xử lý response dài 3385 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1788/2000 samples
#
# 🚀 Đang tạo batch 1789 đến 1794...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3285 chars
# 🔧 Đang xử lý response dài 3285 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1794/2000 samples
#
# 🚀 Đang tạo batch 1795 đến 1800...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3847 chars
# 🔧 Đang xử lý response dài 3847 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1800/2000 samples
#
# 🚀 Đang tạo batch 1801 đến 1806...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4691 chars
# 🔧 Đang xử lý response dài 4691 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1806/2000 samples
#
# 🚀 Đang tạo batch 1807 đến 1812...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4311 chars
# 🔧 Đang xử lý response dài 4311 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1812/2000 samples
#
# 🚀 Đang tạo batch 1813 đến 1818...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3717 chars
# 🔧 Đang xử lý response dài 3717 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1818/2000 samples
#
# 🚀 Đang tạo batch 1819 đến 1824...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4647 chars
# 🔧 Đang xử lý response dài 4647 chars...
# ❌ Parse trực tiếp thất bại
# ❌ Vẫn lỗi JSON sau khi sửa
# ❌ Lỗi parse JSON manual
# ❌ Lỗi attempt 1: Không thể trích xuất JSON từ response
# 🔄 Chuyển sang model: gemini-2.5-flash
# 🔄 Attempt 2 với model gemini-2.5-flash...
# 📄 Raw response length: 3468 chars
# 🔧 Đang xử lý response dài 3468 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1824/2000 samples
#
# 🚀 Đang tạo batch 1825 đến 1830...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4102 chars
# 🔧 Đang xử lý response dài 4102 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1830/2000 samples
#
# 🚀 Đang tạo batch 1831 đến 1836...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3929 chars
# 🔧 Đang xử lý response dài 3929 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1836/2000 samples
#
# 🚀 Đang tạo batch 1837 đến 1842...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4245 chars
# 🔧 Đang xử lý response dài 4245 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1842/2000 samples
#
# 🚀 Đang tạo batch 1843 đến 1848...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3562 chars
# 🔧 Đang xử lý response dài 3562 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1848/2000 samples
#
# 🚀 Đang tạo batch 1849 đến 1854...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4077 chars
# 🔧 Đang xử lý response dài 4077 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1854/2000 samples
#
# 🚀 Đang tạo batch 1855 đến 1860...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3939 chars
# 🔧 Đang xử lý response dài 3939 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1860/2000 samples
#
# 🚀 Đang tạo batch 1861 đến 1866...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 7556 chars
# 🔧 Đang xử lý response dài 7556 chars...
# ❌ Parse trực tiếp thất bại
# ❌ Vẫn lỗi JSON sau khi sửa
# ❌ Lỗi parse JSON manual
# ❌ Lỗi attempt 1: Không thể trích xuất JSON từ response
# 🔄 Chuyển sang model: gemini-2.5-flash
# 🔄 Attempt 2 với model gemini-2.5-flash...
# 📄 Raw response length: 3530 chars
# 🔧 Đang xử lý response dài 3530 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1866/2000 samples
#
# 🚀 Đang tạo batch 1867 đến 1872...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3329 chars
# 🔧 Đang xử lý response dài 3329 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1872/2000 samples
#
# 🚀 Đang tạo batch 1873 đến 1878...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4068 chars
# 🔧 Đang xử lý response dài 4068 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1878/2000 samples
#
# 🚀 Đang tạo batch 1879 đến 1884...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4541 chars
# 🔧 Đang xử lý response dài 4541 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1884/2000 samples
#
# 🚀 Đang tạo batch 1885 đến 1890...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4183 chars
# 🔧 Đang xử lý response dài 4183 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1890/2000 samples
#
# 🚀 Đang tạo batch 1891 đến 1896...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4434 chars
# 🔧 Đang xử lý response dài 4434 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1896/2000 samples
#
# 🚀 Đang tạo batch 1897 đến 1902...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2799 chars
# 🔧 Đang xử lý response dài 2799 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1902/2000 samples
#
# 🚀 Đang tạo batch 1903 đến 1908...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 6544 chars
# 🔧 Đang xử lý response dài 6544 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1908/2000 samples
#
# 🚀 Đang tạo batch 1909 đến 1914...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4339 chars
# 🔧 Đang xử lý response dài 4339 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1914/2000 samples
#
# 🚀 Đang tạo batch 1915 đến 1920...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2565 chars
# 🔧 Đang xử lý response dài 2565 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1920/2000 samples
#
# 🚀 Đang tạo batch 1921 đến 1926...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4035 chars
# 🔧 Đang xử lý response dài 4035 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1926/2000 samples
#
# 🚀 Đang tạo batch 1927 đến 1932...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 2830 chars
# 🔧 Đang xử lý response dài 2830 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1932/2000 samples
#
# 🚀 Đang tạo batch 1933 đến 1938...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3930 chars
# 🔧 Đang xử lý response dài 3930 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1938/2000 samples
#
# 🚀 Đang tạo batch 1939 đến 1944...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5260 chars
# 🔧 Đang xử lý response dài 5260 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1944/2000 samples
#
# 🚀 Đang tạo batch 1945 đến 1950...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5824 chars
# 🔧 Đang xử lý response dài 5824 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1950/2000 samples
#
# 🚀 Đang tạo batch 1951 đến 1956...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4410 chars
# 🔧 Đang xử lý response dài 4410 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1956/2000 samples
#
# 🚀 Đang tạo batch 1957 đến 1962...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4323 chars
# 🔧 Đang xử lý response dài 4323 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1962/2000 samples
#
# 🚀 Đang tạo batch 1963 đến 1968...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4256 chars
# 🔧 Đang xử lý response dài 4256 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1968/2000 samples
#
# 🚀 Đang tạo batch 1969 đến 1974...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3909 chars
# 🔧 Đang xử lý response dài 3909 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1974/2000 samples
#
# 🚀 Đang tạo batch 1975 đến 1980...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 5293 chars
# 🔧 Đang xử lý response dài 5293 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1980/2000 samples
#
# 🚀 Đang tạo batch 1981 đến 1986...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 4741 chars
# 🔧 Đang xử lý response dài 4741 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1986/2000 samples
#
# 🚀 Đang tạo batch 1987 đến 1992...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3723 chars
# 🔧 Đang xử lý response dài 3723 chars...
# ❌ Parse trực tiếp thất bại
# ❌ Vẫn lỗi JSON sau khi sửa
# ❌ Lỗi parse JSON manual
# ❌ Lỗi attempt 1: Không thể trích xuất JSON từ response
# 🔄 Chuyển sang model: gemini-2.5-flash
# 🔄 Attempt 2 với model gemini-2.5-flash...
# 📄 Raw response length: 3222 chars
# 🔧 Đang xử lý response dài 3222 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1992/2000 samples
#
# 🚀 Đang tạo batch 1993 đến 1998...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 3518 chars
# 🔧 Đang xử lý response dài 3518 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 6 samples
# ✅ Đã tạo 1998/2000 samples
#
# 🚀 Đang tạo batch 1999 đến 2000...
# ✅ Sử dụng model: gemini-2.5-flash-lite
# 🔄 Attempt 1 với model gemini-2.5-flash-lite...
# 📄 Raw response length: 1642 chars
# 🔧 Đang xử lý response dài 1642 chars...
# ✅ Parse trực tiếp thành công
# ✅ Đã tạo được 2 samples
# ✅ Đã tạo 2000/2000 samples
#
# 🎉 Hoàn tất! Đã tạo 2000 samples data từ chối với độ đa dạng cao.
